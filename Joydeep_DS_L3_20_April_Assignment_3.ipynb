# %% [markdown]
# <a href="https://colab.research.google.com/github/Joydeep75/SHALA2020/blob/master/Joydeep_DS_L3_20_April_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment - 3: Improving Graphs**
#
# ---
# Course website: [SHALA-2020](https://shala2020.github.io/)
#
# This assignment will get you familiarized with improving plots/graphs in Python.

# %% [markdown]
# ---
# ## Part 1 - Importing packages and loading data
# ---

# %% [markdown]
# ###Import the following libraries:
#
# * ```numpy``` with an alias name ```np```,
# * ```pandas``` with an alias name ```pd```,
# * ```matplotlib.pyplot``` with an alias name ```plt```, and
# * ```seaborn``` with an alias name ```sns```.
#
# *You are free to use any other popular libraries*.

# %%
# Load the libraries with their aliases 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### Using the files ```train.csv``` and ```moviesData.csv```,  peform the following:
#
# * Load these file as ```pandas``` dataframes and store it in variables named ```train``` and ```movies``` respectively.
# * Print the first ten rows of ```train``` and last ten rows of ```movies```.

# %%
# Load train.csv and movies.csv 
url_train = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Assignments/DataScience/L2/train.csv"
train = pd.read_csv(url_train)

# Print the first ten rows of train
train.head(10) #, train.dtypes
# Out:
#    Age  Attrition  ... YearsWithCurrManager  ID
# 0   41          1  ...                    5   0
# 1   49          0  ...                    7   1
# 2   37          1  ...                    0   2
# 3   33          0  ...                    0   3
# 4   27          0  ...                    2   4
# 5   32          0  ...                    6   5
# 6   59          0  ...                    0   6
# 7   30          0  ...                    0   7
# 8   38          0  ...                    8   8
# 9   36          0  ...                    7   9
#
# [10 rows x 34 columns]

# %%
# Load movies.csv
url_movies = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Google_Colab_Notebooks/DataScience/L2/moviesData.csv"
movies = pd.read_csv(url_movies)

# Print the last ten rows of movies 
movies.tail(10)
# Out:
#      Unnamed: 0  ...            actor5
# 590         591  ...        Ben Vereen
# 591         592  ...       Bob Balaban
# 592         593  ...     George Gaynes
# 593         594  ...   Lance Henriksen
# 594         595  ...  Steve Guttenberg
# 595         596  ...       Jack Bailey
# 596         597  ...       Rachel True
# 597         598  ...    Randy McDowell
# 598         599  ...       Ian McNeice
# 599         600  ...    Adam G. Sevani
#
# [10 rows x 31 columns]

# %% [markdown]
# ---
# ## Part 2 - Drawing correlation and heatmap
# ---

# %% [markdown]
# ### Using the correlation matrix, peform the following:
#
# * Find the correlation matrix for the ```movies```.
# * Draw a **heatmap** with the correlation matrix and display the values of correlation coefficients for each pair of features. Make sure the values are properly visible. You might want to adjust the figure size for this.
# * Create a ```mask``` to remove the duplicate values from the **heatmap**.

# %%
# Find out the correlation matrix
moviesCor = movies.corr()
#moviesCor 

# Draw the heatmap 
plt.figure(figsize = (10,10))
sns.heatmap(moviesCor, annot= True)

# %%
# Creating a mask for removing duplicates 
plt.figure(figsize = (10,10))
mask = np.zeros_like(moviesCor, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(movies.corr(), vmin = -1, vmax = 1, center = 0, cmap='coolwarm', annot=True, mask = mask)
# vmin = -1, cmap='coolwarm', annot=True, mask = mask

# %% [markdown]
# ---
# ## Part 3 - Drawing plots and customizing these
# ---

# %% [markdown]
# ### Using a histogram, peform the following:
#
# * Draw a histogram of all the numeric features in ```train```. Please note that this can be done in a single command.
#
# * Find out whether there is any redundant features in ```train```, which can be dropped while building a model.

# %%
# Draw a histogram 
# plt.figure(figsize=(200,200))

train.columns, train.hist(figsize=(20, 20))
# sns.distplot(train)


# Find out the redundant features 
# The redundant features (Flat histogram pictures) are, 
# 1. EmployeeNumber
# 2. ID
# 3. MonthlyRate
# Out:
# (Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#         'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#         'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#         'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#         'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#         'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#         'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
#         'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#         'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#         'ID'],
#        dtype='object'),
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8eb02240>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8eb25c50>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8ead3ef0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8ea8e2b0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8ea3b630>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8ea6b9b0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8ea19d30>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8e9d60b8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8e9d6128>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8e9337f0>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8e961b70>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8e915ef0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8e8d42b0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8e885630>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8e8379b0>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8e86cd30>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8e8290f0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8e7d9470>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8e78e7f0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8e73db70>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8e6f0ef0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8e6b12b0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8e6e3630>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8e6969b0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8e646d30>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8e6060f0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8e5b8470>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8e5ea7f0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8e59bb70>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7f5e8e54fef0>]],
#        dtype=object))

# %% [markdown]
# ### Using a scatter plot, perform the following:
#
# * Draw a scatter plot between between ```imdb_rating``` and ```audience_score```, and also fit a regression line.
# * Change the color of marker to red, size to 200, transparency to 0.3.

# %%
# Scatter plot to fit the regression line 
sns.set_style('whitegrid')
sns.regplot(x = movies['imdb_rating'], 
            y = movies['audience_score'])

# sns.lmplot(x = 'imdb_rating', 
#            y = 'audience_score',
#            data = movies, scatter_kws ={'s':200})

# %%
# Change marker of the scatter plot
sns.set_style('whitegrid')
sns.regplot(x = movies['imdb_rating'],  
            y = movies['audience_score'], 
            scatter_kws ={'color': 'red', 'alpha': 0.5, 's':200})

# %% [markdown]
# ### Using a scatter plot, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw a scatter plot between between ```petal_length``` and ```petal_width``` and color it according to the ```species```.
# * Change the size of marker to 100 and place the legend in ```lower right```.

# %%
# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')

df.dtypes
 
# Use the 'hue' argument to provide a factor variable
sns.lmplot(x='petal_length', 
           y = 'petal_width', 
           data = df, 
           hue = 'species',
           scatter_kws = {'s':100},
           fit_reg=False,
           legend = False)
 
# Move the legend to an empty part of the plot
plt.legend(loc = 'lower right')

# %% [markdown]
# ---
# ## Part 4 - Density Plots
# ---

# %% [markdown]
# ### Using density plots, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw the density plots for all the features ```sepal_width```, ```sepal_length```, ```petal_width```, and ```petal_length```. You can required to use subplots for plotting all the density plots.
# * Try drawing a [CDF](https://en.wikipedia.org/wiki/Cumulative_distribution_function) of these features. There is a [blog on medium](https://medium.com/@rishav.jnit/exploratory-data-analysis-eda-on-iris-dataset-using-python-cadd850c1fc6) on how to plot CDF. It will be covered in tutorial.

# %%
# library and dataset 
df = sns.load_dataset('iris')

# %% [markdown]
# ### Using violin plot, perform the following:
#
# * Load the dataset ```iris```. This has been done for you.
# * Draw the density plots of ```species``` versus ```sepal_length```.
# * Assign each group a color like
#
#     * versicolor - green,
#     * setosa - blue,
#     * virginica - m

# %%
# Draw the normal violin plots

# %%
# Change the color of each group
